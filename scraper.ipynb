# %%
import asyncio
import nest_asyncio
from playwright.async_api import async_playwright
import pandas as pd
import json
import re
from datetime import datetime
from urllib.parse import urljoin, urlparse
import time
from typing import Dict, List, Optional
import csv

nest_asyncio.apply()

BASE_URL = 'https://help.moengage.com'
RATE_LIMIT_DELAY = 1  
MAX_RETRIES = 3

print("setup complete")
# Out:
# setup complete

# %%
async def discover_all_documentation_links():
    async with async_playwright() as p:
        browser = await p.chromium.launch(
            headless=True,
            args=[
                "--disable-blink-features=AutomationControlled",
                "--disable-dev-shm-usage",
                "--no-sandbox"
            ]
        )
        context = await browser.new_context(
            viewport={'width': 1920, 'height': 1080},
            user_agent='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
        )
        page = await context.new_page()
        
        try:
            print("Starting link discovery...")
            await page.goto(f'{BASE_URL}/hc/en-us', wait_until='networkidle')
            
            # grab all <a> tags with hrefs + their text and title
            links = await page.evaluate('''
                () => {
                    return Array.from(document.querySelectorAll('a[href]')).map(link => ({
                        href: link.href,
                        text: link.textContent.trim(),
                        title: link.title || ''
                    }));
                }
            ''')

            # regex patterns for which links we care about
            documentation_patterns = [
                r'https://help\.moengage\.com/hc/en-us/articles/\d+-',
                r'https://developers\.moengage\.com/hc/en-us/articles/\d+-',
                r'https://partners\.moengage\.com/hc/en-us/articles/\d+-'
            ]

            filtered_links = []
            seen_urls = set()

            for link in links:
                href = link['href']
                if any(re.match(pattern, href) for pattern in documentation_patterns):
                    if href not in seen_urls:
                        filtered_links.append({
                            'url': href,
                            'title': link['text'],  # no truncation here
                            'source': (
                                'help' if 'help.moengage' in href else
                                'developers' if 'developers' in href else
                                'partners'
                            )
                        })
                        seen_urls.add(href)

            print(f"Found {len(filtered_links)} unique docs")
            return filtered_links

        except Exception as e:
            print(f"Oops, something blew up during link discovery: {str(e)}")
            return []
        finally:
            await browser.close()

# run the discovery and dump results into a CSV
discovered_links = await discover_all_documentation_links()
df_links = pd.DataFrame(discovered_links)
df_links.to_csv('final.csv', index=False)
print(f"Wrote {len(discovered_links)} links to final.csv")
df_links.head()
# Out:
# Starting link discovery...
# Found 898 unique docs
# Wrote 898 links to final.csv
#                                                  url  \
# 0  https://help.moengage.com/hc/en-us/articles/19...
# 1  https://help.moengage.com/hc/en-us/articles/36...
# 2  https://help.moengage.com/hc/en-us/articles/11...
# 3  https://help.moengage.com/hc/en-us/articles/33...
# 4  https://help.moengage.com/hc/en-us/articles/36...
#
#                                                title source
# 0                                    Contact Support   help
# 1                                      Terms to Know   help
# 2                         Feature or Product in Beta   help
# 3  Sign Up with MoEngage or Create a New Account ...   help
# 4          Set Up 2-Step Verification on Your Device   help

# %%
class ArticleExtractor:
    """Article extractor with structured content parsing"""

    def __init__(self):
        self.retry_count = 0
        self.max_retries = MAX_RETRIES

    async def extract_article_content(self, url: str) -> dict:
        async with async_playwright() as p:
            browser = await p.chromium.launch(headless=True)
            context = await browser.new_context(
                viewport={'width': 1920, 'height': 1080},
                user_agent='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
            )
            page = await context.new_page()

            try:
                print(f"Extracting: {url}")
                await page.goto(url, wait_until='networkidle', timeout=30000)

                content = await page.evaluate('''
                    () => {
                        const article = {};

                        // grab title with fallback selectors
                        const titleSelectors = [
                            'h6.article-title',
                            'h1.article-title',
                            '.article-title',
                            'h1',
                            '.page-title'
                        ];
                        for (const selector of titleSelectors) {
                            const el = document.querySelector(selector);
                            if (el) {
                                article.title = el.textContent.trim();
                                break;
                            }
                        }

                        // get main body element
                        const bodyEl = document.querySelector('div.article__body') ||
                                       document.querySelector('.article-body') ||
                                       document.querySelector('.content');

                        if (bodyEl) {
                            const sections = [];
                            let currentSection = { heading: 'Introduction', content: '', images: [] };
                            const children = Array.from(bodyEl.children);

                            children.forEach(child => {
                                const tag = child.tagName.toLowerCase();

                                if (['h1', 'h2', 'h3', 'h4', 'h5', 'h6'].includes(tag)) {
                                    if (currentSection.content.trim()) {
                                        sections.push({ ...currentSection });
                                    }
                                    currentSection = {
                                        heading: child.textContent.trim(),
                                        content: '',
                                        images: [],
                                        level: parseInt(tag.charAt(1))
                                    };
                                } else {
                                    const text = child.textContent.trim();
                                    if (text) {
                                        currentSection.content += text + '\\n\\n';
                                    }
                                    const imgs = child.querySelectorAll('img');
                                    imgs.forEach(img => {
                                        if (img.src) {
                                            currentSection.images.push({
                                                src: img.src,
                                                alt: img.alt || '',
                                                title: img.title || ''
                                            });
                                        }
                                    });
                                }
                            });

                            if (currentSection.content.trim()) {
                                sections.push(currentSection);
                            }

                            article.sections = sections;
                            article.fullText = bodyEl.textContent.trim();
                            article.htmlContent = bodyEl.innerHTML;
                        }

                        article.url = window.location.href;
                        article.wordCount = article.fullText ? article.fullText.split(/\\s+/).length : 0;
                        article.lastModified = document.querySelector('time')?.getAttribute('datetime') || '';

                        const breadcrumbs = Array.from(document.querySelectorAll('.breadcrumbs a, nav a'))
                                                .map(a => a.textContent.trim())
                                                .filter(Boolean);
                        article.breadcrumbs = breadcrumbs;

                        return article;
                    }
                ''')

                content['extractedAt'] = datetime.now().isoformat()
                content['success'] = True

                return content

            except Exception as e:
                print(f"Error extracting {url}: {str(e)}")
                return {
                    'url': url,
                    'error': str(e),
                    'success': False,
                    'extractedAt': datetime.now().isoformat()
                }
            finally:
                await browser.close()

extractor = ArticleExtractor()

# %%
async def process_articles_batch(urls: list, batch_size: int = 5) -> list:
    # store all results here
    all_results = []
    total_batches = (len(urls) + batch_size - 1) // batch_size

    print(f"Processing {len(urls)} articles in {total_batches} batches of {batch_size}")

    for i in range(0, len(urls), batch_size):
        batch = urls[i:i + batch_size]
        batch_num = (i // batch_size) + 1

        print(f"\nBatch {batch_num}/{total_batches} — processing {len(batch)} articles...")

        # run all extractors in parallel
        batch_tasks = [extractor.extract_article_content(url) for url in batch]
        batch_results = await asyncio.gather(*batch_tasks, return_exceptions=True)

        # handle results + failures
        for j, result in enumerate(batch_results):
            if isinstance(result, Exception):
                print(f"Failed: {batch[j]} — {str(result)}")
                all_results.append({
                    'url': batch[j],
                    'error': str(result),
                    'success': False
                })
            else:
                if result.get('success', False):
                    print(f"Success: {result.get('title', 'Untitled')[:50]}...")
                else:
                    print(f"Partial: {batch[j]}")
                all_results.append(result)

        # avoid hammering the server
        if i + batch_size < len(urls):
            print(f"Sleeping {RATE_LIMIT_DELAY}s before next batch...")
            await asyncio.sleep(RATE_LIMIT_DELAY)

    success_count = sum(1 for r in all_results if r.get('success', False))
    print(f"\nDone! {success_count}/{len(urls)} articles successfully extracted")

    return all_results

# %%
# grab first 3 URLs for a test run
sample_urls = [url['url'] for url in discovered_links[:3]]

print("Running test on sample articles...")
sample_results = await process_articles_batch(sample_urls, batch_size=3)

# show some sample outputs for quick check
for result in sample_results[:3]:
    if result.get('success'):
        print(f"\nTitle: {result.get('title', 'N/A')}")
        print(f"Word count: {result.get('wordCount', 0)}")
        print(f"Sections found: {len(result.get('sections', []))}")
        if result.get('sections'):
            section_titles = [s['heading'] for s in result['sections'][:3]]
            print("Sample section headings:", section_titles)
# Out:
# Running test on sample articles...
# Processing 3 articles in 1 batches of 3
#
# Batch 1/1 — processing 3 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/115005943283-Feature-or-Product-in-Beta
# Extracting: https://help.moengage.com/hc/en-us/articles/19708702327572-Raise-a-Support-Ticket-Through-MoEngage-Dashboard
# Extracting: https://help.moengage.com/hc/en-us/articles/360040071212-Terms-to-Know
# Success: Raise a Support Ticket Through MoEngage Dashboard...
# Success: Terms to Know...
# Success: Feature or Product in Beta...
#
# Done! 3/3 articles successfully extracted
#
# Title: Raise a Support Ticket Through MoEngage Dashboard
# Word count: 388
# Sections found: 1
# Sample section headings: ['Introduction']
#
# Title: Terms to Know
# Word count: 604
# Sections found: 1
# Sample section headings: ['Introduction']
#
# Title: Feature or Product in Beta
# Word count: 251
# Sections found: 1
# Sample section headings: ['Introduction']

# %%
# running this on all the articles

all_urls = [url['url'] for url in discovered_links[:898]]

print("all the urls...")
all_results = await process_articles_batch(all_urls, batch_size=2)

for result in all_results[:3]:
    if result.get('success'):
        print(f"\nTitle: {result.get('title', 'N/A')}")
        print(f"Word count: {result.get('wordCount', 0)}")
        print(f"Sections found: {len(result.get('sections', []))}")
        if result.get('sections'):
            section_titles = [s['heading'] for s in result['sections'][:3]]
            print("section headings:", section_titles)
# Out:
# all the urls...
# Processing 898 articles in 449 batches of 2
#
# Batch 1/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360040071212-Terms-to-Know
# Extracting: https://help.moengage.com/hc/en-us/articles/19708702327572-Raise-a-Support-Ticket-Through-MoEngage-Dashboard
# Success: Raise a Support Ticket Through MoEngage Dashboard...
# Success: Terms to Know...
# Sleeping 1s before next batch...
#
# Batch 2/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/33436161901332-Sign-Up-with-MoEngage-or-Create-a-New-Account-in-MoEngage
# Extracting: https://help.moengage.com/hc/en-us/articles/115005943283-Feature-or-Product-in-Beta
# Success: Feature or Product in Beta...
# Success: Sign Up with MoEngage or Create a New Account in M...
# Sleeping 1s before next batch...
#
# Batch 3/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36908840992276-Set-Up-2-Step-Verification-on-Your-Device
# Extracting: https://help.moengage.com/hc/en-us/articles/36906116607380-Finish-Your-Account-Setup-as-an-Invited-User
# Success: Set Up 2-Step Verification on Your Device...
# Success: Finish Your Account Setup as an Invited User...
# Sleeping 1s before next batch...
#
# Batch 4/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/206559303-Dashboard-Overview
# Extracting: https://help.moengage.com/hc/en-us/articles/34852261258004-Log-in-to-MoEngage
# Success: Log in to MoEngage...
# Success: Dashboard Overview...
# Sleeping 1s before next batch...
#
# Batch 5/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36781211059476-Manage-Your-Profile
# Extracting: https://help.moengage.com/hc/en-us/articles/210845683-Live-and-Test-environments
# Success: Live and Test environments...
# Success: Manage Your Profile...
# Sleeping 1s before next batch...
#
# Batch 6/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36774960874004-Navigate-to-Your-Account-s-Login-Page
# Extracting: https://help.moengage.com/hc/en-us/articles/210860483-Manage-Your-Workspaces
# Success: Manage Your Workspaces...
# Success: Navigate to Your Account's Login Page...
# Sleeping 1s before next batch...
#
# Batch 7/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/37222689059348-Reset-2-Step-Verification-on-Your-Device
# Extracting: https://help.moengage.com/hc/en-us/articles/36981215191188-Forgot-Password
# Success: Forgot Password?...
# Success: Reset 2-Step Verification on Your Device...
# Sleeping 1s before next batch...
#
# Batch 8/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36908631897876-Recovery-Codes
# Extracting: https://help.moengage.com/hc/en-us/articles/115002571883-Suggest-a-Feature
# Success: Recovery Codes...
# Success: Suggest a Feature...
# Sleeping 1s before next batch...
#
# Batch 9/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360043067671-Default-Android-SDK
# Extracting: https://help.moengage.com/hc/en-us/articles/33508135433236-Migrate-or-Transfer-Push-Tokens
# Success: Migrate or Transfer Push Tokens...
# Success: Default Android SDK...
# Sleeping 1s before next batch...
#
# Batch 10/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360042512472-Default-iOS-SDK
# Extracting: https://help.moengage.com/hc/en-us/articles/360042954831-Default-Web-SDK
# Success: Default Web SDK...
# Success: Default iOS SDK...
# Sleeping 1s before next batch...
#
# Batch 11/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/4414974770836-Test-users
# Extracting: https://help.moengage.com/hc/en-us/articles/22894582080020-Shopify
# Success: Shopify...
# Success: Test users...
# Sleeping 1s before next batch...
#
# Batch 12/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360033589511-Reinstall-Tracking
# Extracting: https://help.moengage.com/hc/en-us/articles/206271566-Integration-Checklist
# Success: Integration Checklist...
# Success: Reinstall Tracking...
# Sleeping 1s before next batch...
#
# Batch 13/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360057117171-MoEngage-Integration-Validation-and-Tracker
# Extracting: https://help.moengage.com/hc/en-us/articles/32665738201108-Android-Native-Integration-Validation
# Success: Android Native Integration Validation...
# Success: MoEngage Integration Validation and Tracker...
# Sleeping 1s before next batch...
#
# Batch 14/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360051732232-Install-Uninstall-Reinstall-Integration-Validation
# Extracting: https://help.moengage.com/hc/en-us/articles/360042322691-User-Attribute-Profile-Integration-Validation
# Success: Install/Uninstall/Reinstall Integration Validation...
# Success: User Attribute/Profile Integration Validation...
# Sleeping 1s before next batch...
#
# Batch 15/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360051972172-Android-Push-Notifications-Integration-Validation
# Extracting: https://help.moengage.com/hc/en-us/articles/360051787432-User-Events-Integration-Validation
# Success: User Events Integration Validation...
# Success: Android Push Notifications Integration Validation...
# Sleeping 1s before next batch...
#
# Batch 16/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360051973572-Web-Push-Notifications-Integration-Validation
# Extracting: https://help.moengage.com/hc/en-us/articles/360052433591-iOS-Push-Notifications-Integration-Validation
# Success: iOS Push Notifications Integration Validation...
# Success: Web Push Notifications Integration Validation...
# Sleeping 1s before next batch...
#
# Batch 17/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360052236731-Push-Templates-Integration-Validation
# Extracting: https://help.moengage.com/hc/en-us/articles/360051974872-In-App-Notifications-Integration-Validation
# Success: Push Templates Integration Validation...
# Success: In-App Notifications Integration Validation...
# Sleeping 1s before next batch...
#
# Batch 18/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/28332074311060-API-Key-Dashboard
# Extracting: https://help.moengage.com/hc/en-us/articles/36472555136020-Workspace-Settings
# Success: Workspace Settings...
# Success: API Key Dashboard...
# Sleeping 1s before next batch...
#
# Batch 19/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/210855743-Access-Roles
# Extracting: https://help.moengage.com/hc/en-us/articles/360041804831-Manage-Members
# Success: Manage Members...
# Success: Access Roles...
# Sleeping 1s before next batch...
#
# Batch 20/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360028586211-Teams-in-MoEngage
# Extracting: https://help.moengage.com/hc/en-us/articles/30310276466964-Teams-2-0-in-MoEngage
# Success: Teams in MoEngage...
# Success: Teams 2.0 in MoEngage...
# Sleeping 1s before next batch...
#
# Batch 21/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360021206931-Campaign-Approval-Workflow
# Extracting: https://help.moengage.com/hc/en-us/articles/8770662326548-Audit-Logs
# Success: Campaign Approval Workflow...
# Success: Audit Logs...
# Sleeping 1s before next batch...
#
# Batch 22/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36713285151892-Set-Up-the-Login-Method
# Extracting: https://help.moengage.com/hc/en-us/articles/35162846579860-Overview
# Success: Overview...
# Success: Set Up the Login Method...
# Sleeping 1s before next batch...
#
# Batch 23/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360046714492-2-Step-Verification-or-Two-Factor-Authentication-2FA
# Extracting: https://help.moengage.com/hc/en-us/articles/360054517871-Firewall
# Success: 2-Step Verification or Two-Factor Authentication (...
# Success: Firewall...
# Sleeping 1s before next batch...
#
# Batch 24/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/30724167504788-MoEngage-Access
# Extracting: https://help.moengage.com/hc/en-us/articles/360035238511-Single-Sign-On-SSO
# Success: MoEngage Access...
# Success: Single Sign-On (SSO)...
# Sleeping 1s before next batch...
#
# Batch 25/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/9971914380308-Account-Lockout
# Extracting: https://help.moengage.com/hc/en-us/articles/36871193933716-Automatic-Logout
# Success: Account Lockout...
# Success: Automatic Logout...
# Sleeping 1s before next batch...
#
# Batch 26/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/35329024618772-IP-Whitelisting-in-MoEngage
# Extracting: https://help.moengage.com/hc/en-us/articles/23447255847060-System-for-Cross-domain-Identity-Management-SCIM
# Success: System for Cross-domain Identity Management (SCIM)...
# Success: IP Whitelisting in MoEngage...
# Sleeping 1s before next batch...
#
# Batch 27/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/8996996992276-Security-Best-Practices
# Extracting: https://help.moengage.com/hc/en-us/articles/27437434857364-Organization-Details
# Success: Security Best Practices...
# Success: Organization Details...
# Sleeping 1s before next batch...
#
# Batch 28/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/33183774689044-How-To-Resolve-reCAPTCHA-Issues-in-the-Browser-When-Logging-In-to-the-Dashboard
# Extracting: https://help.moengage.com/hc/en-us/articles/27411474660884-Manage-Subscription
# Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed\nCall log:\n  - navigating to "https://help.moengage.com/hc/en-us/articles/115005943283-Feature-or-Product-in-Beta", waiting until "networkidle"\n')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/115005943283-Feature-or-Product-in-Beta", waiting until "networkidle"
#
# Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed\nCall log:\n  - navigating to "https://help.moengage.com/hc/en-us/articles/19708702327572-Raise-a-Support-Ticket-Through-MoEngage-Dashboard", waiting until "networkidle"\n')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/19708702327572-Raise-a-Support-Ticket-Through-MoEngage-Dashboard", waiting until "networkidle"
#
# Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed\nCall log:\n  - navigating to "https://help.moengage.com/hc/en-us/articles/360040071212-Terms-to-Know", waiting until "networkidle"\n')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/360040071212-Terms-to-Know", waiting until "networkidle"
# Success: Manage Subscription...
# Success: How To Resolve reCAPTCHA Issues in the Browser Whe...
# Sleeping 1s before next batch...
#
# Batch 29/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/31224595537940-Why-Does-Switching-Between-LIVE-and-TEST-Environments-Fail
# Extracting: https://help.moengage.com/hc/en-us/articles/31223472156052-Why-Is-the-User-Unable-to-Log-in-to-the-Dashboard
# Success: Why Does Switching Between LIVE and TEST Environme...
# Success: Why Is the User Unable to Log in to the Dashboard?...
# Sleeping 1s before next batch...
#
# Batch 30/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/22679333212564-Suspicious-Login-Verification
# Extracting: https://help.moengage.com/hc/en-us/articles/29140773691156-Why-Is-the-OTP-Not-Received-on-Email-for-2FA
# Success: Why Is the OTP Not Received on Email for 2FA?...
# Success: Suspicious Login Verification...
# Sleeping 1s before next batch...
#
# Batch 31/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/19962101544340-User-unable-to-log-in
# Extracting: https://help.moengage.com/hc/en-us/articles/36578160215060-Enable-User-Merging
# Success: User unable to log in...
# Success: Enable User Merging...
# Sleeping 1s before next batch...
#
# Batch 32/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36578806968212-Acquisition-Tracking
# Extracting: https://help.moengage.com/hc/en-us/articles/36579295266580-Uninstall-Tracking
# Success: Acquisition Tracking...
# Success: Uninstall Tracking...
# Sleeping 1s before next batch...
#
# Batch 33/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/32740952421652-Data-Management-Alerts
# Extracting: https://help.moengage.com/hc/en-us/articles/31633492991124-Overview-Data-Management
# Success: Overview - Data Management...
# Success: Data Management Alerts...
# Sleeping 1s before next batch...
#
# Batch 34/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/35579781173012-Campaign-Audience-Limit
# Extracting: https://help.moengage.com/hc/en-us/articles/15919660670356-Frequency-capping
# Success: Campaign Audience Limit...
# Success: Frequency capping...
# Sleeping 1s before next batch...
#
# Batch 35/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/15919572705556-Do-Not-Disturb
# Extracting: https://help.moengage.com/hc/en-us/articles/15917463954836-Minimum-delay-between-campaigns
# Success: Do Not Disturb...
# Success: Minimum delay between campaigns...
# Sleeping 1s before next batch...
#
# Batch 36/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/15916160319764-Throttling
# Extracting: https://help.moengage.com/hc/en-us/articles/213902323-Send-campaign-in-recipient-s-time-zone
# Success: Throttling...
# Success: Send campaign in recipient's time zone...
# Sleeping 1s before next batch...
#
# Batch 37/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36579900636948-Manage-Tags
# Extracting: https://help.moengage.com/hc/en-us/articles/360052305312-Global-Control-Group
# Success: Global Control Group...
# Success: Manage Tags...
# Sleeping 1s before next batch...
#
# Batch 38/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36580390790548-Locales
# Extracting: https://help.moengage.com/hc/en-us/articles/36580648645780-Add-a-Content-API
# Success: Locales...
# Success: Add a Content API...
# Sleeping 1s before next batch...
#
# Batch 39/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/13706614569236-Configure-Custom-Domain-Link-Branding
# Extracting: https://help.moengage.com/hc/en-us/articles/36044803949332-E-164-Phone-Number-Format
# Success: Configure Custom Domain (Link Branding)...
# Success: E.164 Phone Number Format...
# Sleeping 1s before next batch...
#
# Batch 40/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/23949234646292-Authorization-Configuration-with-OAuth-2-0
# Extracting: https://help.moengage.com/hc/en-us/articles/28166642757908-Mobile-Number-Standardization
# Success: Mobile Number Standardization...
# Success: Authorization Configuration with OAuth 2.0...
# Sleeping 1s before next batch...
#
# Batch 41/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/21359224674196-Setting-Up-General-UTM-Parameters-at-Account-Level
# Extracting: https://help.moengage.com/hc/en-us/articles/23720304504980-Adding-UTM-Parameters-to-Email
# Success: Setting Up General UTM Parameters at Account Level...
# Success: Adding UTM Parameters to Email...
# Sleeping 1s before next batch...
#
# Batch 42/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/23719384342804-Adding-UTM-Parameters-at-the-Flow-Level
# Extracting: https://help.moengage.com/hc/en-us/articles/19997146519828-Campaign-Attribution-Settings
# Success: Adding UTM Parameters at the Flow Level...
# Success: Campaign Attribution Settings...
# Sleeping 1s before next batch...
#
# Batch 43/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/19320181606932-Overview-Alert-Management
# Extracting: https://help.moengage.com/hc/en-us/articles/16275295710484-Campaign-Attribution-Settings
# Success: Campaign Attribution Settings...
# Success: Overview - Alert Management...
# Sleeping 1s before next batch...
#
# Batch 44/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/19094494054036-Managing-Alerts
# Extracting: https://help.moengage.com/hc/en-us/articles/19094285198484-Create-an-Alert
# Success: Create an Alert...
# Success: Managing Alerts...
# Sleeping 1s before next batch...
#
# Batch 45/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36979428872596-Dashboard-Subscriptions
# Extracting: https://help.moengage.com/hc/en-us/articles/36979454293652-Proactive-Assistant-Settings
# Success: Dashboard Subscriptions...
# Success: Proactive Assistant Settings...
# Sleeping 1s before next batch...
#
# Batch 46/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/10726947613844-Settings-Inform
# Extracting: https://help.moengage.com/hc/en-us/articles/17461246281364-Overview-Data
# Success: Settings - Inform...
# Success: Overview - Data...
# Sleeping 1s before next batch...
#
# Batch 47/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360057030512-Data-Centers-in-MoEngage
# Extracting: https://help.moengage.com/hc/en-us/articles/28329867358740-Event-Naming-Conventions
# Success: Data Centers in MoEngage...
# Success: Event Naming Conventions...
# Sleeping 1s before next batch...
#
# Batch 48/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/24151864954644-Fair-Usage-Policy-FUP
# Extracting: https://help.moengage.com/hc/en-us/articles/360037143412-Data-Archival-Policies
# Success: Fair Usage Policy (FUP)...
# Success: Data Archival Policies...
# Sleeping 1s before next batch...
#
# Batch 49/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360037314991-Data-Tracking-Policies
# Extracting: https://help.moengage.com/hc/en-us/articles/29787626775828-Support-for-Object-Data-Type
# Success: Data Tracking Policies...
# Success: Support for Object Data Type...
# Sleeping 1s before next batch...
#
# Batch 50/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/12088416349460-User-Merging
# Extracting: https://help.moengage.com/hc/en-us/articles/360044285511-User-Profile
# Success: User Profile...
# Success: User Merging...
# Sleeping 1s before next batch...
#
# Batch 51/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/24050999467284-Unified-Identity-Identity-Resolution
# Extracting: https://help.moengage.com/hc/en-us/articles/17152954613908-Derived-User-Attributes
# Success: Unified Identity (Identity Resolution)...
# Success: Derived User Attributes...
# Sleeping 1s before next batch...
#
# Batch 52/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/29785239989524-User-Install-Status
# Extracting: https://help.moengage.com/hc/en-us/articles/25210370038164-A-Complete-Guide-to-Event-Tracking
# Success: User Install Status...
# Success: A Complete Guide to Event Tracking...
# Sleeping 1s before next batch...
#
# Batch 53/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/207836953-Derived-Events-Attributes
# Extracting: https://help.moengage.com/hc/en-us/articles/5426529660052-Event-Time-and-Received-Time
# Success: Derived Events & Attributes...
# Success: Event Time and Received Time...
# Sleeping 1s before next batch...
#
# Batch 54/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/35684138384532-Databricks-Imports
# Extracting: https://help.moengage.com/hc/en-us/articles/12246167449236-Overview-Imports
# Success: Overview - Imports...
# Success: Databricks Imports...
# Sleeping 1s before next batch...
#
# Batch 55/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/18324470276884-Snowflake-Imports
# Extracting: https://help.moengage.com/hc/en-us/articles/31354584806548-Import-Datetime-Attributes
# Success: Snowflake Imports...
# Success: Import Datetime Attributes...
# Sleeping 1s before next batch...
#
# Batch 56/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/19192630201620-Import-User-Data-Using-CSV
# Extracting: https://help.moengage.com/hc/en-us/articles/30929992530068-Import-Event-Data-Using-CSV
# Success: Import User Data Using CSV...
# Success: Import Event Data Using CSV...
# Sleeping 1s before next batch...
#
# Batch 57/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/10170540879380-S3-Imports
# Extracting: https://help.moengage.com/hc/en-us/articles/12241329478676-SFTP-Imports
# Success: S3 Imports...
# Success: SFTP Imports...
# Sleeping 1s before next batch...
#
# Batch 58/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/21864536245396-Using-PGP-Encryption-in-MoEngage
# Extracting: https://help.moengage.com/hc/en-us/articles/15777729284116-Auxiliary-Data
# Success: Using PGP Encryption in MoEngage...
# Success: Auxiliary Data...
# Sleeping 1s before next batch...
#
# Batch 59/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/20729252566164-User-imports-Revamp-Summary
# Extracting: https://help.moengage.com/hc/en-us/articles/35683199426452-Databricks-Exports
# Success: User imports - Revamp Summary...
# Success: Databricks Exports...
# Sleeping 1s before next batch...
#
# Batch 60/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/29369034030228-SFTP-Exports
# Extracting: https://help.moengage.com/hc/en-us/articles/18603435928212-Snowflake-Exports
# Success: SFTP Exports...
# Success: Snowflake Exports...
# Sleeping 1s before next batch...
#
# Batch 61/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/8098260902548-S3-Exports
# Extracting: https://help.moengage.com/hc/en-us/articles/13344979528852-Redshift-Exports
# Success: S3 Exports...
# Success: Redshift Exports...
# Sleeping 1s before next batch...
#
# Batch 62/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/13344999442068-Google-Cloud-Storage-GCS-Exports
# Extracting: https://help.moengage.com/hc/en-us/articles/13345092550164-BigQuery-Exports
# Success: Google Cloud Storage (GCS) Exports...
# Success: BigQuery Exports...
# Sleeping 1s before next batch...
#
# Batch 63/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/15975781928468-Data-Export-Glossary
# Extracting: https://help.moengage.com/hc/en-us/articles/24824971360404-Analyze-the-Volume-of-Data-Exports
# Success: Analyze the Volume of Data Exports...
# Success: Data Export Glossary...
# Sleeping 1s before next batch...
#
# Batch 64/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/13003920120212-Outbound-Segment-Sync
# Extracting: https://help.moengage.com/hc/en-us/articles/26112132023700-Syncing-Segments-from-One-MoEngage-App-to-Another
# Success: Outbound Segment Sync...
# Success: Syncing Segments from One MoEngage App to Another...
# Sleeping 1s before next batch...
#
# Batch 65/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/9144870585748-Personal-Data-or-Personally-Identifiable-Information-PII
# Extracting: https://help.moengage.com/hc/en-us/articles/12844580781588-PII-Data-Encryption
# Success: Personal Data or Personally Identifiable Informati...
# Success: PII Data Encryption...
# Sleeping 1s before next batch...
#
# Batch 66/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/9111881294996-PII-Tokenized-Sending
# Extracting: https://help.moengage.com/hc/en-us/articles/5902573446804-PII-Masking
# Success: PII Masking...
# Success: PII Tokenized Sending...
# Sleeping 1s before next batch...
#
# Batch 67/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/31950809723540-PII-Masking-on-Personalised-Preview
# Extracting: https://help.moengage.com/hc/en-us/articles/360052917232-CCPA
# Success: PII Masking on Personalised Preview...
# Success: CCPA...
# Sleeping 1s before next batch...
#
# Batch 68/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360000878126-GDPR
# Extracting: https://help.moengage.com/hc/en-us/articles/23893067070996-Apple-Privacy-Manifest-Update
# Success: GDPR...
# Success: Apple Privacy Manifest Update...
# Sleeping 1s before next batch...
#
# Batch 69/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/34141591428244-Why-Are-Location-Values-Not-Updated-on-the-User-Profile
# Extracting: https://help.moengage.com/hc/en-us/articles/7457641031828-Android-Advertising-ID-Tracking
# Success: Android Advertising ID Tracking...
# Success: Why Are Location Values Not Updated on the User Pr...
# Sleeping 1s before next batch...
#
# Batch 70/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/34141054369556-How-to-Use-the-Delete-API-Through-a-Connector-Campaign-to-Delete-Multiple-User-Profiles
# Extracting: https://help.moengage.com/hc/en-us/articles/34140563887508-Why-Does-the-Periodic-SFTP-Import-Fail-with-a-Error
# Success: How to Use the Delete API Through a Connector Camp...
# Success: Why Does the Periodic SFTP Import Fail with a Erro...
# Sleeping 1s before next batch...
#
# Batch 71/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/34140193269908-Why-Is-the-User-Import-Status-Showing-as-Processing
# Extracting: https://help.moengage.com/hc/en-us/articles/34139863043860-Why-Does-a-NoneType-Comparison-Error-occur-During-SFTP-S3-Import
# Success: Why Is the User Import Status Showing as 'Processi...
# Success: Why Does a NoneType Comparison Error occur During ...
# Sleeping 1s before next batch...
#
# Batch 72/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/34138076326420-Why-Creating-a-User-Again-After-Deletion-Using-the-Open-GDPR-API-Is-Not-Possible
# Extracting: https://help.moengage.com/hc/en-us/articles/34137953427476-Why-Is-an-Anonymous-User-Profile-Created-with-an-Uninstall-Event-Linked-to-a-Campaign-ID
# Success: Why Creating a User Again After Deletion Using the...
# Success: Why Is an Anonymous User Profile Created with an U...
# Sleeping 1s before next batch...
#
# Batch 73/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/33181303991188-How-To-Generate-an-Auth-Token-for-the-Data-API
# Extracting: https://help.moengage.com/hc/en-us/articles/33181758930324-Why-Are-Event-Data-Uploads-From-S3-Failing-Due-to-a-Timeout-Error
# Success: Why Are Event Data Uploads From S3 Failing Due to ...
# Success: How To Generate an Auth Token for the Data API?...
# Sleeping 1s before next batch...
#
# Batch 74/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/33181078489492-How-To-Verify-User-Deletion-in-MoEngage
# Extracting: https://help.moengage.com/hc/en-us/articles/33150229183124-What-Is-the-Importance-of-the-MoEngage-API-Key-and-What-Happens-if-It-Is-Updated
# Success: How To Verify User Deletion in MoEngage?...
# Success: What Is the Importance of the MoEngage API Key, an...
# Sleeping 1s before next batch...
#
# Batch 75/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/32057130939284-Why-Is-the-New-Data-Type-Not-Reflecting-in-Data-Management
# Extracting: https://help.moengage.com/hc/en-us/articles/32056923662228-Why-Does-the-Empty-Rows-Error-Occur-When-Importing-a-File
# Success: Why Is the New Data Type Not Reflecting in Data Ma...
# Success: Why Does the "Empty Rows" Error Occur When Importi...
# Sleeping 1s before next batch...
#
# Batch 76/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/31226294748948-What-Unique-ID-Values-Does-the-System-Accept
# Extracting: https://help.moengage.com/hc/en-us/articles/31226180214804-What-Are-the-Key-Points-of-the-MoEngage-Data-Tracking-Policy
# Success: What Unique ID Values Does the System Accept?...
# Success: What Are the Key Points of the MoEngage Data Track...
# Sleeping 1s before next batch...
#
# Batch 77/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/31225557984020-Why-Are-Users-Not-Merged-After-Using-the-User-Merge-API
# Extracting: https://help.moengage.com/hc/en-us/articles/31224750532116-Why-Are-New-Events-or-User-Attributes-Not-Reflected-on-the-Dashboard
# Success: Why Are Users Not Merged After Using the User Merg...
# Success: Why Are New Events or User Attributes Not Reflecte...
# Sleeping 1s before next batch...
#
# Batch 78/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/29218895827860-How-to-Fix-Common-Errors-with-Simple-Storage-Service-S3-Import
# Extracting: https://help.moengage.com/hc/en-us/articles/29142653329940-What-Are-the-Common-File-Import-Errors-in-MoEngage
# Success: How to Fix Common Errors with Simple Storage Servi...
# Success: What Are the Common File Import Errors in MoEngage...
# Sleeping 1s before next batch...
#
# Batch 79/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/28473037826324-What-Are-the-Key-Distinctions-Between-Encryption-and-Masking-on-the-Data-Management-Page
# Extracting: https://help.moengage.com/hc/en-us/articles/28999686115348-Why-Is-Domain-Whitelisting-Recommended-Over-IP-Whitelisting-for-the-Data-API
# Success: Why Is Domain Whitelisting Recommended Over IP Whi...
# Success: What Are the Key Distinctions Between Encryption a...
# Sleeping 1s before next batch...
#
# Batch 80/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360044354631-Event-Category-Name-Update
# Extracting: https://help.moengage.com/hc/en-us/articles/360045162812-Error-Messages-in-the-Browser-Console-due-to-CORS-Policy
# Success: Error Messages in the Browser Console due to CORS ...
# Success: Event & Category Name Update...
# Sleeping 1s before next batch...
#
# Batch 81/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/115002309023-How-can-I-import-custom-data-to-MoEngage
# Extracting: https://help.moengage.com/hc/en-us/articles/115002978403-Triggered-Campaigns-not-working-on-S2S-events-how-to-resolve
# Success: How can I import custom data to MoEngage?...
# Success: Triggered Campaigns not working on S2S events, how...
# Sleeping 1s before next batch...
#
# Batch 82/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/17152492634772-Basics-of-Segmentation
# Extracting: https://help.moengage.com/hc/en-us/articles/4416971195284-Types-of-Segments
# Success: Basics of Segmentation...
# Success: Types of Segments...
# Sleeping 1s before next batch...
#
# Batch 83/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/206169646-Create-Segments
# Extracting: https://help.moengage.com/hc/en-us/articles/11210398575508-All-Segments
# Success: All Segments...
# Success: Create Segments...
# Sleeping 1s before next batch...
#
# Batch 84/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360058291252-Affinity-Segments
# Extracting: https://help.moengage.com/hc/en-us/articles/207606916-File-Segments
# Success: Affinity Segments...
# Success: File Segments...
# Sleeping 1s before next batch...
#
# Batch 85/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/206528613-Custom-Segments
# Extracting: https://help.moengage.com/hc/en-us/articles/360037365132-RFM-Segments
# Error extracting https://help.moengage.com/hc/en-us/articles/360037365132-RFM-Segments: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/360037365132-RFM-Segments", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/360037365132-RFM-Segments
# Success: Custom Segments...
# Sleeping 1s before next batch...
#
# Batch 86/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/20491797002132-Real-Time-Segment-Evaluation
# Extracting: https://help.moengage.com/hc/en-us/articles/25994970019092-Warehouse-Segments
# Success: Real-Time Segment Evaluation...
# Success: Warehouse Segments...
# Sleeping 1s before next batch...
#
# Batch 87/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/16342986786964-Segment-Nesting
# Extracting: https://help.moengage.com/hc/en-us/articles/360046335412-Filters-in-Segmentation
# Success: Segment Nesting...
# Success: Filters in Segmentation...
# Sleeping 1s before next batch...
#
# Batch 88/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360001062103-Value-Suggestions
# Extracting: https://help.moengage.com/hc/en-us/articles/9722166234004-Aggregation-Operations
# Success: Aggregation Operations...
# Success: Value Suggestions...
# Sleeping 1s before next batch...
#
# Batch 89/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360045962992-User-Reachability
# Extracting: https://help.moengage.com/hc/en-us/articles/26829603206932-Object-Data-Type-in-Segmentation
# Success: Object Data Type in Segmentation...
# Success: User Reachability...
# Sleeping 1s before next batch...
#
# Batch 90/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/24299876915604-Push-Reachability
# Extracting: https://help.moengage.com/hc/en-us/articles/24300615894164-Email-Reachability
# Error extracting https://help.moengage.com/hc/en-us/articles/24299876915604-Push-Reachability: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/24299876915604-Push-Reachability", waiting until "networkidle"
#
# Error extracting https://help.moengage.com/hc/en-us/articles/24300615894164-Email-Reachability: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/24300615894164-Email-Reachability", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/24299876915604-Push-Reachability
# Partial: https://help.moengage.com/hc/en-us/articles/24300615894164-Email-Reachability
# Sleeping 1s before next batch...
#
# Batch 91/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/24949778690452-WhatsApp-Reachability
# Extracting: https://help.moengage.com/hc/en-us/articles/24711436728980-SMS-Reachability
# Success: SMS Reachability...
# Success: WhatsApp Reachability...
# Sleeping 1s before next batch...
#
# Batch 92/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/29143283431572-Why-Is-There-a-Mismatch-in-the-Events-and-Users-Count-Between-Data-Warehouses-and-the-MoEngage-Dashboard
# Extracting: https://help.moengage.com/hc/en-us/articles/29144791845524-How-to-Troubleshoot-Campaigns-with-Segmentation-Scenarios-Containing-Date-of-Birth
# Success: How to Troubleshoot Campaigns with Segmentation Sc...
# Success: Why Is There a Mismatch in the Events and Users Co...
# Sleeping 1s before next batch...
#
# Batch 93/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/33114992690324-Overview
# Extracting: https://help.moengage.com/hc/en-us/articles/33083500921108-Overview
# Success: Overview...
# Success: Overview...
# Sleeping 1s before next batch...
#
# Batch 94/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/34174958923156-Overview
# Extracting: https://help.moengage.com/hc/en-us/articles/33185107111188-Analysis
# Success: Overview...
# Success: Analysis...
# Sleeping 1s before next batch...
#
# Batch 95/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/33214017936532-Analysis
# Extracting: https://help.moengage.com/hc/en-us/articles/34174962989204-Overview
# Error extracting https://help.moengage.com/hc/en-us/articles/34174962989204-Overview: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/34174962989204-Overview", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/34174962989204-Overview
# Success: Analysis...
# Sleeping 1s before next batch...
#
# Batch 96/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/34207204503188-Advanced
# Extracting: https://help.moengage.com/hc/en-us/articles/34174988942740-Overview
# Error extracting https://help.moengage.com/hc/en-us/articles/34174988942740-Overview: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/34174988942740-Overview", waiting until "networkidle"
#
# Success: Advanced...
# Partial: https://help.moengage.com/hc/en-us/articles/34174988942740-Overview
# Sleeping 1s before next batch...
#
# Batch 97/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/34274460529172-Advanced
# Extracting: https://help.moengage.com/hc/en-us/articles/33946697047444-Analysis
# Success: Analysis...
# Success: Advanced...
# Sleeping 1s before next batch...
#
# Batch 98/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/35438072333076-Analysis
# Extracting: https://help.moengage.com/hc/en-us/articles/35438085954196-Overview
# Error extracting https://help.moengage.com/hc/en-us/articles/35438085954196-Overview: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/35438085954196-Overview", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/35438085954196-Overview
# Success: Analysis...
# Sleeping 1s before next batch...
#
# Batch 99/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36436670170516-Advanced
# Extracting: https://help.moengage.com/hc/en-us/articles/35724347745812-Overview
# Error extracting https://help.moengage.com/hc/en-us/articles/35724347745812-Overview: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/35724347745812-Overview", waiting until "networkidle"
#
# Success: Advanced...
# Partial: https://help.moengage.com/hc/en-us/articles/35724347745812-Overview
# Sleeping 1s before next batch...
#
# Batch 100/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36437040437012-Advanced
# Extracting: https://help.moengage.com/hc/en-us/articles/35724344698772-Analysis
# Success: Analysis...
# Success: Advanced...
# Sleeping 1s before next batch...
#
# Batch 101/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36048662361748-Analysis
# Extracting: https://help.moengage.com/hc/en-us/articles/36048677165332-Overview
# Error extracting https://help.moengage.com/hc/en-us/articles/36048677165332-Overview: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/36048677165332-Overview", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/36048677165332-Overview
# Success: Analysis...
# Sleeping 1s before next batch...
#
# Batch 102/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/209986613-Uninstall
# Extracting: https://help.moengage.com/hc/en-us/articles/206134153-Acquisition
# Success: Acquisition...
# Success: Uninstall...
# Sleeping 1s before next batch...
#
# Batch 103/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/18129193565204-Compare-Mode-in-Analytics
# Extracting: https://help.moengage.com/hc/en-us/articles/36503194744980-Actionable-Analytics
# Error extracting https://help.moengage.com/hc/en-us/articles/18129193565204-Compare-Mode-in-Analytics: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/18129193565204-Compare-Mode-in-Analytics", waiting until "networkidle"
#
# Success: Actionable Analytics...
# Partial: https://help.moengage.com/hc/en-us/articles/18129193565204-Compare-Mode-in-Analytics
# Sleeping 1s before next batch...
#
# Batch 104/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/29362737514388-Alerts-in-Analytics
# Extracting: https://help.moengage.com/hc/en-us/articles/205424326-User-Data-Exports
# Success: Alerts in Analytics...
# Success: User Data Exports...
# Sleeping 1s before next batch...
#
# Batch 105/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/33185178907028-Key-Metrics
# Extracting: https://help.moengage.com/hc/en-us/articles/33185141957524-Overview
# Success: Overview...
# Success: Key Metrics...
# Sleeping 1s before next batch...
#
# Batch 106/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/206560453-Key-Metrics-Old-Version
# Extracting: https://help.moengage.com/hc/en-us/articles/34174451233684-Campaign-Stats
# Success: Key Metrics (Old Version)...
# Success: Campaign Stats...
# Sleeping 1s before next batch...
#
# Batch 107/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/34174479717780-Reachability
# Extracting: https://help.moengage.com/hc/en-us/articles/34174452762132-Best-Time-Analysis
# Success: Best Time Analysis...
# Success: Reachability...
# Sleeping 1s before next batch...
#
# Batch 108/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/27854721709716-My-Studio
# Extracting: https://help.moengage.com/hc/en-us/articles/360027636312-Custom-Dashboards
# Error extracting https://help.moengage.com/hc/en-us/articles/27854721709716-My-Studio: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/27854721709716-My-Studio", waiting until "networkidle"
#
# Success: Custom Dashboards...
# Partial: https://help.moengage.com/hc/en-us/articles/27854721709716-My-Studio
# Sleeping 1s before next batch...
#
# Batch 109/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360061652731-Open-Analytics
# Extracting: https://help.moengage.com/hc/en-us/articles/18060739634580-Understanding-Count-Differences-in-Behavior-and-Funnel-Analyses
# Success: Open Analytics...
# Success: Understanding Count Differences in Behavior and Fu...
# Sleeping 1s before next batch...
#
# Batch 110/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360048049252-Key-Metrics-Queries-for-Open-Analytics
# Extracting: https://help.moengage.com/hc/en-us/articles/360061825952-Different-count-in-Analytics-Segmentation-Campaigns-stats-Flows
# Success: Different count in Analytics, Segmentation, Campai...
# Success: Key Metrics Queries for Open Analytics...
# Sleeping 1s before next batch...
#
# Batch 111/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360046719432-Split-Analysis-on-Attributes
# Extracting: https://help.moengage.com/hc/en-us/articles/360047789072-Reachability-Queries-for-Open-Analytics
# Success: Reachability Queries for Open Analytics...
# Success: Split Analysis on Attributes...
# Sleeping 1s before next batch...
#
# Batch 112/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360041850152-Different-count-in-Analytics-Segmentation
# Extracting: https://help.moengage.com/hc/en-us/articles/360035738832-Explore-the-Number-of-Notifications-Received-by-Users
# Success: Different count in Analytics & Segmentation...
# Success: Explore the Number of Notifications Received by Us...
# Sleeping 1s before next batch...
#
# Batch 113/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/34147439461012-Why-does-the-0-1-bucket-in-total-events-per-user-behavior-analysis-show-no-users
# Extracting: https://help.moengage.com/hc/en-us/articles/14417885506580-Understanding-Data-Differences-between-Google-Analytics-and-MoEngage
# Success: Understanding Data Differences between Google Anal...
# Success: Why does the 0-1 bucket in 'total events per user'...
# Sleeping 1s before next batch...
#
# Batch 114/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/32264711139476-What-causes-unexpected-event-sequences-in-user-paths
# Extracting: https://help.moengage.com/hc/en-us/articles/34146402974484-Why-is-there-a-discrepancy-in-the-behavior-table-for-ingested-data
# Success: Why is there a discrepancy in the behavior table f...
# Success: What causes unexpected event sequences in user pat...
# Sleeping 1s before next batch...
#
# Batch 115/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/31223777114772-Why-do-uninstall-event-counts-in-MoEngage-differ-from-Google-s-data-or-show-zero
# Extracting: https://help.moengage.com/hc/en-us/articles/32227318584596-Why-do-the-campaign-stats-and-campaign-analytics-show-different-counts
# Success: Why do the campaign stats and campaign analytics s...
# Success: Why do uninstall event counts in MoEngage differ f...
# Sleeping 1s before next batch...
#
# Batch 116/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/29141335642132-Why-does-the-behavior-analysis-show-the-In-App-shown-event-after-delivery-but-the-campaign-performance-chart-doesn-t
# Extracting: https://help.moengage.com/hc/en-us/articles/29216641086356-Why-Does-Real-Time-Uninstall-Tracking-Differ-from-the-Uninstall-Status-on-the-Dashboard
# Success: Why Does Real-Time Uninstall Tracking Differ from ...
# Success: Why does the behavior analysis show the In-App sho...
# Sleeping 1s before next batch...
#
# Batch 117/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360043026012-Uninstall-Tracking
# Extracting: https://help.moengage.com/hc/en-us/articles/28967936837908-Why-Do-Uninstall-Counts-Differ-Between-the-Key-Metrics-Dashboard-and-Segmentation
# Success: Why Do Uninstall Counts Differ Between the Key Met...
# Success: Uninstall Tracking...
# Sleeping 1s before next batch...
#
# Batch 118/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360058167752-MoEngage-Channels
# Extracting: https://help.moengage.com/hc/en-us/articles/360058616131-Delivery-Types-MoEngage-Channels
# Success: MoEngage Channels...
# Success: Delivery Types - MoEngage Channels...
# Sleeping 1s before next batch...
#
# Batch 119/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/23040004020372-Campaign-Drafts
# Extracting: https://help.moengage.com/hc/en-us/articles/360058057412-Campaign-Tags
# Success: Campaign Drafts...
# Success: Campaign Tags...
# Sleeping 1s before next batch...
#
# Batch 120/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360052829132-Control-Groups
# Extracting: https://help.moengage.com/hc/en-us/articles/360058752652-Create-an-Event-Triggered-Campaign
# Success: Control Groups...
# Success: Create an Event-Triggered Campaign...
# Sleeping 1s before next batch...
#
# Batch 121/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/16714065887252-Overview-Business-Events
# Extracting: https://help.moengage.com/hc/en-us/articles/17122169428628-Business-Event-Triggered-Campaigns
# Success: Overview - Business Events...
# Success: Business Event Triggered Campaigns...
# Sleeping 1s before next batch...
#
# Batch 122/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/115003667986-Localize-Campaign-Messages
# Extracting: https://help.moengage.com/hc/en-us/articles/115003622346-Content-APIs
# Success: Content APIs...
# ...
# Sleeping 1s before next batch...
#
# Batch 409/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/23198126978580-How-to-Nudge-Users-to-Continue-Watching-Content
# Extracting: https://help.moengage.com/hc/en-us/articles/23197631633556-How-to-Drive-Upsells-Through-Recommendations
# Error extracting https://help.moengage.com/hc/en-us/articles/23197631633556-How-to-Drive-Upsells-Through-Recommendations: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/23197631633556-How-to-Drive-Upsells-Through-Recommendations", waiting until "networkidle"
#
# Success: How to Nudge Users to Continue Watching Content...
# Partial: https://help.moengage.com/hc/en-us/articles/23197631633556-How-to-Drive-Upsells-Through-Recommendations
# Sleeping 1s before next batch...
#
# Batch 410/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/31253030098580-How-to-Recommend-Apparels-by-Size-and-Availability
# Extracting: https://help.moengage.com/hc/en-us/articles/23197545619860-How-to-Use-Recommendations-to-Drive-First-Purchase
# Success: How to Use Recommendations to Drive First Purchase...
# Success: How to Recommend Apparels by Size and Availability...
# Sleeping 1s before next batch...
#
# Batch 411/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/23197462153492-How-to-Recommend-Content-to-Watch-Next
# Extracting: https://help.moengage.com/hc/en-us/articles/31252812591380-How-to-Recommend-Content-to-Users-Based-on-the-Sequence-of-Preferences
# Success: How to Recommend Content to Watch Next...
# Success: How to Recommend Content to Users Based on the Seq...
# Sleeping 1s before next batch...
#
# Batch 412/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/27552043212948-How-to-Activate-Dormant-Users-with-Memories
# Extracting: https://help.moengage.com/hc/en-us/articles/23552997576596-Merlin-AI-Copywriter-for-Global-and-Local-Language
# Success: How to Activate Dormant Users with Memories...
# Success: Merlin AI Copywriter for Global and Local Language...
# Sleeping 1s before next batch...
#
# Batch 413/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/27554506070292-How-to-Create-a-Segment-Based-on-Links-Clicked-in-Emails
# Extracting: https://help.moengage.com/hc/en-us/articles/15881047705236-Create-a-Birthday-Email-Campaign
# Success: How to Create a Segment Based on Links Clicked in ...
# Success: Create a Birthday Email Campaign...
# Sleeping 1s before next batch...
#
# Batch 414/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360058165372-How-to-Find-a-User-in-MoEngage
# Extracting: https://help.moengage.com/hc/en-us/articles/15658971297044-Create-a-Birthday-Push-Campaign
# Success: Create a Birthday Push Campaign...
# Success: How to Find a User in MoEngage...
# Sleeping 1s before next batch...
#
# Batch 415/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/211276883-How-to-Identify-Web-Push-subscribers
# Extracting: https://help.moengage.com/hc/en-us/articles/31413336292756-How-to-Encourage-Users-to-Repeat-Orders-for-Categories-Without-a-Due-Date
# Success: How to Encourage Users to Repeat Orders for Catego...
# Success: How to Identify Web Push subscribers...
# Sleeping 1s before next batch...
#
# Batch 416/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/207002086-Segment-Users-Who-Uninstalled-Your-Application
# Extracting: https://help.moengage.com/hc/en-us/articles/206615186-How-to-Analyze-web-activity
# Error extracting https://help.moengage.com/hc/en-us/articles/207002086-Segment-Users-Who-Uninstalled-Your-Application: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/207002086-Segment-Users-Who-Uninstalled-Your-Application", waiting until "networkidle"
#
# Error extracting https://help.moengage.com/hc/en-us/articles/206615186-How-to-Analyze-web-activity: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/206615186-How-to-Analyze-web-activity", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/206615186-How-to-Analyze-web-activity
# Partial: https://help.moengage.com/hc/en-us/articles/207002086-Segment-Users-Who-Uninstalled-Your-Application
# Sleeping 1s before next batch...
#
# Batch 417/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/205780779-Segment-Users-of-Specific-App-Versions
# Extracting: https://help.moengage.com/hc/en-us/articles/206503455-Segment-Users-to-Notify-App-Updates
# Error extracting https://help.moengage.com/hc/en-us/articles/205780779-Segment-Users-of-Specific-App-Versions: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/205780779-Segment-Users-of-Specific-App-Versions", waiting until "networkidle"
#
# Error extracting https://help.moengage.com/hc/en-us/articles/206503455-Segment-Users-to-Notify-App-Updates: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/206503455-Segment-Users-to-Notify-App-Updates", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/205780779-Segment-Users-of-Specific-App-Versions
# Partial: https://help.moengage.com/hc/en-us/articles/206503455-Segment-Users-to-Notify-App-Updates
# Sleeping 1s before next batch...
#
# Batch 418/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/31224769381268-How-to-Send-Messages-in-WhatsApp-Based-on-Users-Last-Activity-on-the-App
# Extracting: https://help.moengage.com/hc/en-us/articles/29144829685652-How-to-Harness-Loyalty-Data-to-Drive-Customer-Engagement
# Success: How to Harness Loyalty Data to Drive Customer Enga...
# Success: How to Send Messages in WhatsApp Based on Users' L...
# Sleeping 1s before next batch...
#
# Batch 419/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/32664799340564-Artificial-Intelligence-Resolution-Agent-AIRA
# Extracting: https://help.moengage.com/hc/en-us/articles/20904910460308-Conversational-Messaging-on-WhatsApp
# Success: Conversational Messaging on WhatsApp...
# Success: Artificial Intelligence Resolution Agent (AIRA)...
# Sleeping 1s before next batch...
#
# Batch 420/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/28298317432724-Raise-a-Support-Ticket-from-the-MoEngage-Login-Page
# Extracting: https://help.moengage.com/hc/en-us/articles/24263408623892-Deprecation-of-Email-Support
# Success: Raise a Support Ticket from the MoEngage Login Pag...
# Success: Deprecation of Email Support...
# Sleeping 1s before next batch...
#
# Batch 421/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/4402656152468-Support-Issue-Types-and-Priority
# Extracting: https://help.moengage.com/hc/en-us/articles/19709507846164-How-Can-I-See-My-Support-Tickets
# Success: Support Issue Types and Priority...
# Success: How Can I See My Support Tickets?...
# Sleeping 1s before next batch...
#
# Batch 422/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/36680856854420-April-2025
# Extracting: https://help.moengage.com/hc/en-us/articles/35545634234516-March-2025
# Success: April 2025...
# Success: March 2025...
# Sleeping 1s before next batch...
#
# Batch 423/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/34745189212692-February-2025
# Extracting: https://help.moengage.com/hc/en-us/articles/33680811489556-January-2025
# Success: February 2025...
# Success: January 2025...
# Sleeping 1s before next batch...
#
# Batch 424/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/32508752919316-November-2024
# Extracting: https://help.moengage.com/hc/en-us/articles/32950457283092-December-2024
# Success: December 2024...
# Success: November 2024...
# Sleeping 1s before next batch...
#
# Batch 425/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/30296256388756-September-2024
# Extracting: https://help.moengage.com/hc/en-us/articles/31818875677076-October-2024
# Success: October 2024...
# Success: September 2024...
# Sleeping 1s before next batch...
#
# Batch 426/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/30279420150932-August-2024
# Extracting: https://help.moengage.com/hc/en-us/articles/29001969072788-July-2024
# Success: August 2024...
# Success: July 2024...
# Sleeping 1s before next batch...
#
# Batch 427/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/29001997918612-May-2024
# Extracting: https://help.moengage.com/hc/en-us/articles/29001950361108-June-2024
# Success: June 2024...
# Success: May 2024...
# Sleeping 1s before next batch...
#
# Batch 428/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/25718223993620-April-2024
# Extracting: https://help.moengage.com/hc/en-us/articles/24259540531732-March-2024
# Error extracting https://help.moengage.com/hc/en-us/articles/24259540531732-March-2024: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/24259540531732-March-2024", waiting until "networkidle"
#
# Success: April 2024...
# Partial: https://help.moengage.com/hc/en-us/articles/24259540531732-March-2024
# Sleeping 1s before next batch...
#
# Batch 429/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/24047743148308-February-2024
# Extracting: https://help.moengage.com/hc/en-us/articles/22914827482900-January-2024
# Success: February 2024...
# Success: January 2024...
# Sleeping 1s before next batch...
#
# Batch 430/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/19683815524116-November-2023
# Extracting: https://help.moengage.com/hc/en-us/articles/21471661974292-December-2023
# Success: December 2023...
# Success: November 2023...
# Sleeping 1s before next batch...
#
# Batch 431/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/19683250916372-September-2023
# Extracting: https://help.moengage.com/hc/en-us/articles/21394384729748-October-2023
# Success: October 2023...
# Success: September 2023...
# Sleeping 1s before next batch...
#
# Batch 432/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/19487110766868-August-2023
# Extracting: https://help.moengage.com/hc/en-us/articles/18895469106324-July-2023
# Success: August 2023...
# Success: July 2023...
# Sleeping 1s before next batch...
#
# Batch 433/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/16843991698708-May-2023
# Extracting: https://help.moengage.com/hc/en-us/articles/17868951937940-June-2023
# Success: June 2023...
# Success: May 2023...
# Sleeping 1s before next batch...
#
# Batch 434/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/14573188617492-March-2023
# Extracting: https://help.moengage.com/hc/en-us/articles/16174681317780-April-2023
# Success: April 2023...
# Success: March 2023...
# Sleeping 1s before next batch...
#
# Batch 435/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/13521838268308-January-2023
# Extracting: https://help.moengage.com/hc/en-us/articles/14420762714900-February-2023
# Success: February 2023...
# Success: January 2023...
# Sleeping 1s before next batch...
#
# Batch 436/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/11766249838740-November-2022
# Extracting: https://help.moengage.com/hc/en-us/articles/12598400148372-December-2022
# Success: December 2022...
# Success: November 2022...
# Sleeping 1s before next batch...
#
# Batch 437/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/11112048438292-October-2022
# Extracting: https://help.moengage.com/hc/en-us/articles/10223244557972-September-2022
# Success: October 2022...
# Success: September 2022...
# Sleeping 1s before next batch...
#
# Batch 438/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/9322155764500-August-2022
# Extracting: https://help.moengage.com/hc/en-us/articles/7777823025172-July-2022
# Success: August 2022...
# Success: July 2022...
# Sleeping 1s before next batch...
#
# Batch 439/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/9322143048340-June-2022
# Extracting: https://help.moengage.com/hc/en-us/articles/7777758406292-May-2022
# Success: June 2022...
# Success: May 2022...
# Sleeping 1s before next batch...
#
# Batch 440/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/5516053117972-March-2022
# Extracting: https://help.moengage.com/hc/en-us/articles/6840175241364-April-2022
# Success: April 2022...
# Success: March 2022...
# Sleeping 1s before next batch...
#
# Batch 441/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/4628317274388-February-2022
# Extracting: https://help.moengage.com/hc/en-us/articles/4418357957012-January-2022
# Success: February 2022...
# Success: January 2022...
# Sleeping 1s before next batch...
#
# Batch 442/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/4415621582228-November-2021
# Extracting: https://help.moengage.com/hc/en-us/articles/4417935883412-December-2021
# Success: December 2021...
# Success: November 2021...
# Sleeping 1s before next batch...
#
# Batch 443/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/4412375841684-October-2021
# Extracting: https://help.moengage.com/hc/en-us/articles/4408752959636-September-2021
# Success: October 2021...
# Success: September 2021...
# Sleeping 1s before next batch...
#
# Batch 444/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/4405640082196-July-2021
# Extracting: https://help.moengage.com/hc/en-us/articles/4407267925396-August-2021
# Success: August 2021...
# Success: July 2021...
# Sleeping 1s before next batch...
#
# Batch 445/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/4402241665300-May-2021
# Extracting: https://help.moengage.com/hc/en-us/articles/4403484307476-June-2021
# Success: June 2021...
# Success: May 2021...
# Sleeping 1s before next batch...
#
# Batch 446/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360060988671-March-2021
# Extracting: https://help.moengage.com/hc/en-us/articles/360060929732-April-2021
# Success: April 2021...
# Success: March 2021...
# Sleeping 1s before next batch...
#
# Batch 447/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360056535272-January-2021
# Extracting: https://help.moengage.com/hc/en-us/articles/360057666932-February-2021
# Success: February 2021...
# Success: January 2021...
# Sleeping 1s before next batch...
#
# Batch 448/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360049601451-August-2020
# Extracting: https://help.moengage.com/hc/en-us/articles/360051635531-September-2020
# Success: September 2020...
# Success: August 2020...
# Sleeping 1s before next batch...
#
# Batch 449/449 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360049011771-July-2020
# Extracting: https://help.moengage.com/hc/en-us/articles/360047067832-June-2020
# Success: July 2020...
# Success: June 2020...
#
# Done! 864/898 articles successfully extracted
#
# Title: Raise a Support Ticket Through MoEngage Dashboard
# Word count: 388
# Sections found: 1
# section headings: ['Introduction']
#
# Title: Terms to Know
# Word count: 604
# Sections found: 1
# section headings: ['Introduction']
#
# Title: Feature or Product in Beta
# Word count: 251
# Sections found: 1
# section headings: ['Introduction']

# %%
def save_extracted_content(results: list, filename: str = 'extracted_articles.json'):
    # filter out only successful runs
    successful = [r for r in results if r.get('success', False)]

    summary = {
        'extraction_summary': {
            'total_articles': len(results),
            'successful_extractions': len(successful),
            'failed_extractions': len(results) - len(successful),
            'average_word_count': (
                sum(r.get('wordCount', 0) for r in successful) / len(successful)
                if successful else 0
            ),
            'extraction_timestamp': datetime.now().isoformat()
        },
        'articles': results
    }

    # write full detailed JSON dump
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(summary, f, indent=2, ensure_ascii=False)

    # prep a light CSV summary for quick checks
    csv_data = []
    for article in successful:
        csv_data.append({
            'url': article.get('url', ''),
            'title': article.get('title', ''),
            'word_count': article.get('wordCount', 0),
            'section_count': len(article.get('sections', [])),
            'has_images': any(len(s.get('images', [])) > 0 for s in article.get('sections', [])),
            'breadcrumbs': ' > '.join(article.get('breadcrumbs', []))
        })

    df_articles = pd.DataFrame(csv_data)
    csv_filename = filename.replace('.json', '_summary.csv')
    df_articles.to_csv(csv_filename, index=False)

    print(f"Saved detailed JSON to {filename}")
    print(f"Saved summary CSV to {csv_filename}")
    print(f"Success rate: {len(successful)}/{len(results)} ({(len(successful)/len(results)*100):.1f}%)")

    return summary

# save the sample run results
all_summary = save_extracted_content(all_results, 'extracted_articles.json')
# Out:
# Saved detailed JSON to extracted_articles.json
# Saved summary CSV to extracted_articles_summary.csv
# Success rate: 864/898 (96.2%)

# %%
# okay we missed some here, lets fix them

import pandas as pd
import json
from datetime import datetime

df_original = pd.read_csv('final.csv')
df_extracted = pd.read_csv('extracted_articles_summary.csv')

original_urls = set(df_original['url'].tolist())
extracted_urls = set(df_extracted['url'].tolist())

missed_urls = list(original_urls - extracted_urls)

print(f"Total original: {len(original_urls)}")
print(f"Extracted: {len(extracted_urls)}")
print(f"Missed: {len(missed_urls)}")

if missed_urls:
    print("\nFirst few missed URLs:")
    for i, url in enumerate(missed_urls[:10]):
        print(f"{i + 1}. {url}")

    print(f"\nProcessing {len(missed_urls)} missed articles...")
    missed_results = await process_articles_batch(missed_urls, batch_size=2)

    with open('extracted_articles.json', 'r', encoding='utf-8') as f:
        existing_data = json.load(f)

    all_combined = existing_data['articles'] + missed_results
    successful = [r for r in all_combined if r.get('success', False)]

    summary = {
        'extraction_summary': {
            'total_articles': len(all_combined),
            'successful': len(successful),
            'failed': len(all_combined) - len(successful),
            'avg_word_count': (
                sum(r.get('wordCount', 0) for r in successful) / len(successful)
                if successful else 0
            ),
            'timestamp': datetime.now().isoformat(),
            'retry_done': True
        },
        'articles': all_combined
    }

    with open('extracted_articles_complete.json', 'w', encoding='utf-8') as f:
        json.dump(summary, f, indent=2, ensure_ascii=False)

    csv_data = []
    for article in successful:
        csv_data.append({
            'url': article.get('url', ''),
            'title': article.get('title', ''),
            'word_count': article.get('wordCount', 0),
            'section_count': len(article.get('sections', [])),
            'has_images': any(len(s.get('images', [])) > 0 for s in article.get('sections', [])),
            'breadcrumbs': ' > '.join(article.get('breadcrumbs', []))
        })

    df_complete = pd.DataFrame(csv_data)
    df_complete.to_csv('extracted_articles_complete_summary.csv', index=False)

    print(f"\nRetry done. Success: {len(successful)}/{len(all_combined)}")
    print(f"Improved by: {len(successful) - len(df_extracted)}")

    still_missing = list(original_urls - set(df_complete['url'].tolist()))
    if still_missing:
        print(f"Still missing {len(still_missing)} URLs.")
    else:
        print("All done. No missing URLs left.")

else:
    print("Nothing missed.")
# Out:
# Total original: 898
# Extracted: 864
# Missed: 34
#
# First few missed URLs:
# 1. https://help.moengage.com/hc/en-us/articles/34174988942740-Overview
# 2. https://help.moengage.com/hc/en-us/articles/34174962989204-Overview
# 3. https://help.moengage.com/hc/en-us/articles/206503455-Segment-Users-to-Notify-App-Updates
# 4. https://help.moengage.com/hc/en-us/articles/18129193565204-Compare-Mode-in-Analytics
# 5. https://help.moengage.com/hc/en-us/articles/29145844762900-Display-a-Non-Intrusive-Countdown-Timer-Banner
# 6. https://help.moengage.com/hc/en-us/articles/24865660345876-How-to-Use-Recommendations-to-Announce-Price-Drop
# 7. https://help.moengage.com/hc/en-us/articles/11772245742100-Add-a-Countdown-Timer-to-Emails
# 8. https://help.moengage.com/hc/en-us/articles/33132363356564-View-Personalize-in-action
# 9. https://help.moengage.com/hc/en-us/articles/25637711880724-How-to-Reduce-Bounce-Rates-on-Websites
# 10. https://help.moengage.com/hc/en-us/articles/35724347745812-Overview
#
# Processing 34 missed articles...
# Processing 34 articles in 17 batches of 2
#
# Batch 1/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/34174962989204-Overview
# Extracting: https://help.moengage.com/hc/en-us/articles/34174988942740-Overview
# Error extracting https://help.moengage.com/hc/en-us/articles/34174962989204-Overview: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/34174962989204-Overview", waiting until "networkidle"
#
# Error extracting https://help.moengage.com/hc/en-us/articles/34174988942740-Overview: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/34174988942740-Overview", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/34174988942740-Overview
# Partial: https://help.moengage.com/hc/en-us/articles/34174962989204-Overview
# Sleeping 1s before next batch...
#
# Batch 2/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/206503455-Segment-Users-to-Notify-App-Updates
# Extracting: https://help.moengage.com/hc/en-us/articles/18129193565204-Compare-Mode-in-Analytics
# Success: Segment Users to Notify App Updates...
# Success: Compare Mode in Analytics...
# Sleeping 1s before next batch...
#
# Batch 3/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/24865660345876-How-to-Use-Recommendations-to-Announce-Price-Drop
# Extracting: https://help.moengage.com/hc/en-us/articles/29145844762900-Display-a-Non-Intrusive-Countdown-Timer-Banner
# Error extracting https://help.moengage.com/hc/en-us/articles/29145844762900-Display-a-Non-Intrusive-Countdown-Timer-Banner: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/29145844762900-Display-a-Non-Intrusive-Countdown-Timer-Banner", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/29145844762900-Display-a-Non-Intrusive-Countdown-Timer-Banner
# Success: How to Use Recommendations to Announce Price Drop...
# Sleeping 1s before next batch...
#
# Batch 4/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/11772245742100-Add-a-Countdown-Timer-to-Emails
# Extracting: https://help.moengage.com/hc/en-us/articles/33132363356564-View-Personalize-in-action
# Error extracting https://help.moengage.com/hc/en-us/articles/11772245742100-Add-a-Countdown-Timer-to-Emails: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/11772245742100-Add-a-Countdown-Timer-to-Emails", waiting until "networkidle"
#
# Error extracting https://help.moengage.com/hc/en-us/articles/33132363356564-View-Personalize-in-action: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/33132363356564-View-Personalize-in-action", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/11772245742100-Add-a-Countdown-Timer-to-Emails
# Partial: https://help.moengage.com/hc/en-us/articles/33132363356564-View-Personalize-in-action
# Sleeping 1s before next batch...
#
# Batch 5/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/25637711880724-How-to-Reduce-Bounce-Rates-on-Websites
# Extracting: https://help.moengage.com/hc/en-us/articles/35724347745812-Overview
# Error extracting https://help.moengage.com/hc/en-us/articles/35724347745812-Overview: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/35724347745812-Overview", waiting until "networkidle"
#
# Success: How to Reduce Bounce Rates on Websites...
# Partial: https://help.moengage.com/hc/en-us/articles/35724347745812-Overview
# Sleeping 1s before next batch...
#
# Batch 6/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/30760290716948-How-to-Encourage-Anonymous-Users-to-Log-In-to-the-Website
# Extracting: https://help.moengage.com/hc/en-us/articles/30753746167188-How-to-Show-Sale-Offers-from-a-Specific-Time
# Error extracting https://help.moengage.com/hc/en-us/articles/30760290716948-How-to-Encourage-Anonymous-Users-to-Log-In-to-the-Website: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/30760290716948-How-to-Encourage-Anonymous-Users-to-Log-In-to-the-Website", waiting until "networkidle"
#
# Error extracting https://help.moengage.com/hc/en-us/articles/30753746167188-How-to-Show-Sale-Offers-from-a-Specific-Time: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/30753746167188-How-to-Show-Sale-Offers-from-a-Specific-Time", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/30753746167188-How-to-Show-Sale-Offers-from-a-Specific-Time
# Partial: https://help.moengage.com/hc/en-us/articles/30760290716948-How-to-Encourage-Anonymous-Users-to-Log-In-to-the-Website
# Sleeping 1s before next batch...
#
# Batch 7/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/30759667577876-How-to-Create-a-Survey-Using-the-Drag-Drop-Editor-to-Understand-Customer-Preferences
# Extracting: https://help.moengage.com/hc/en-us/articles/33647366123412-Adding-Widgets
# Error extracting https://help.moengage.com/hc/en-us/articles/30759667577876-How-to-Create-a-Survey-Using-the-Drag-Drop-Editor-to-Understand-Customer-Preferences: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/30759667577876-How-to-Create-a-Survey-Using-the-Drag-Drop-Editor-to-Understand-Customer-Preferences", waiting until "networkidle"
#
# Error extracting https://help.moengage.com/hc/en-us/articles/33647366123412-Adding-Widgets: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/33647366123412-Adding-Widgets", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/33647366123412-Adding-Widgets
# Partial: https://help.moengage.com/hc/en-us/articles/30759667577876-How-to-Create-a-Survey-Using-the-Drag-Drop-Editor-to-Understand-Customer-Preferences
# Sleeping 1s before next batch...
#
# Batch 8/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/30760620896788-How-to-Show-an-OSM-Highlighting-the-Benefits-of-a-Plan-and-Offer-a-Discount-for-Upgrading
# Extracting: https://help.moengage.com/hc/en-us/articles/24299876915604-Push-Reachability
# Error extracting https://help.moengage.com/hc/en-us/articles/30760620896788-How-to-Show-an-OSM-Highlighting-the-Benefits-of-a-Plan-and-Offer-a-Discount-for-Upgrading: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/30760620896788-How-to-Show-an-OSM-Highlighting-the-Benefits-of-a-Plan-and-Offer-a-Discount-for-Upgrading", waiting until "networkidle"
#
# Success: Push Reachability...
# Partial: https://help.moengage.com/hc/en-us/articles/30760620896788-How-to-Show-an-OSM-Highlighting-the-Benefits-of-a-Plan-and-Offer-a-Discount-for-Upgrading
# Sleeping 1s before next batch...
#
# Batch 9/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/24300615894164-Email-Reachability
# Extracting: https://help.moengage.com/hc/en-us/articles/28066282037908-How-to-Personalize-Website-User-s-Current-Browsing-Session
# Error extracting https://help.moengage.com/hc/en-us/articles/28066282037908-How-to-Personalize-Website-User-s-Current-Browsing-Session: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/28066282037908-How-to-Personalize-Website-User-s-Current-Browsing-Session", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/28066282037908-How-to-Personalize-Website-User-s-Current-Browsing-Session
# Success: Email Reachability...
# Sleeping 1s before next batch...
#
# Batch 10/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/23197224076308-Bring-Users-Back-with-Exit-Intent-Communications
# Extracting: https://help.moengage.com/hc/en-us/articles/30758997134356-How-to-Increase-the-Adoption-of-a-Feature-Using-the-Drag-Drop-Editor
# Error extracting https://help.moengage.com/hc/en-us/articles/30758997134356-How-to-Increase-the-Adoption-of-a-Feature-Using-the-Drag-Drop-Editor: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/30758997134356-How-to-Increase-the-Adoption-of-a-Feature-Using-the-Drag-Drop-Editor", waiting until "networkidle"
#
# Success: Bring Users Back with Exit Intent Communications...
# Partial: https://help.moengage.com/hc/en-us/articles/30758997134356-How-to-Increase-the-Adoption-of-a-Feature-Using-the-Drag-Drop-Editor
# Sleeping 1s before next batch...
#
# Batch 11/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/28476977883412-How-to-Set-Up-Purchase-Confirmation-Emails
# Extracting: https://help.moengage.com/hc/en-us/articles/19156797325588-Configure-SSL-Branded-Links-for-SendGrid
# Error extracting https://help.moengage.com/hc/en-us/articles/19156797325588-Configure-SSL-Branded-Links-for-SendGrid: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/19156797325588-Configure-SSL-Branded-Links-for-SendGrid", waiting until "networkidle"
#
# Success: How to Set Up Purchase Confirmation Emails...
# Partial: https://help.moengage.com/hc/en-us/articles/19156797325588-Configure-SSL-Branded-Links-for-SendGrid
# Sleeping 1s before next batch...
#
# Batch 12/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/27854721709716-My-Studio
# Extracting: https://help.moengage.com/hc/en-us/articles/36048677165332-Overview
# Error extracting https://help.moengage.com/hc/en-us/articles/36048677165332-Overview: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/36048677165332-Overview", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/36048677165332-Overview
# Success: My Studio...
# Sleeping 1s before next batch...
#
# Batch 13/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/205780779-Segment-Users-of-Specific-App-Versions
# Extracting: https://help.moengage.com/hc/en-us/articles/28066179709716-How-to-Show-Recently-Viewed-Products-on-Website
# Success: How to Show Recently Viewed Products on Website...
# Success: Segment Users of Specific App Versions...
# Sleeping 1s before next batch...
#
# Batch 14/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/30685385779988-How-to-Configure-Different-Pop-Up-Messages-Based-on-Location
# Extracting: https://help.moengage.com/hc/en-us/articles/206615186-How-to-Analyze-web-activity
# Error extracting https://help.moengage.com/hc/en-us/articles/30685385779988-How-to-Configure-Different-Pop-Up-Messages-Based-on-Location: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/30685385779988-How-to-Configure-Different-Pop-Up-Messages-Based-on-Location", waiting until "networkidle"
#
# Success: How to Analyze web activity...
# Partial: https://help.moengage.com/hc/en-us/articles/30685385779988-How-to-Configure-Different-Pop-Up-Messages-Based-on-Location
# Sleeping 1s before next batch...
#
# Batch 15/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/360037365132-RFM-Segments
# Extracting: https://help.moengage.com/hc/en-us/articles/23197631633556-How-to-Drive-Upsells-Through-Recommendations
# Error extracting https://help.moengage.com/hc/en-us/articles/360037365132-RFM-Segments: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/360037365132-RFM-Segments", waiting until "networkidle"
#
# Partial: https://help.moengage.com/hc/en-us/articles/360037365132-RFM-Segments
# Success: How to Drive Upsells Through Recommendations...
# Sleeping 1s before next batch...
#
# Batch 16/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/13504504954900-Editing-a-Flow
# Extracting: https://help.moengage.com/hc/en-us/articles/24259540531732-March-2024
# Error extracting https://help.moengage.com/hc/en-us/articles/13504504954900-Editing-a-Flow: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/13504504954900-Editing-a-Flow", waiting until "networkidle"
#
# Success: March 2024...
# Partial: https://help.moengage.com/hc/en-us/articles/13504504954900-Editing-a-Flow
# Sleeping 1s before next batch...
#
# Batch 17/17 — processing 2 articles...
# Extracting: https://help.moengage.com/hc/en-us/articles/207002086-Segment-Users-Who-Uninstalled-Your-Application
# Extracting: https://help.moengage.com/hc/en-us/articles/35438085954196-Overview
# Error extracting https://help.moengage.com/hc/en-us/articles/35438085954196-Overview: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://help.moengage.com/hc/en-us/articles/35438085954196-Overview", waiting until "networkidle"
#
# Success: Segment Users Who Uninstalled Your Application...
# Partial: https://help.moengage.com/hc/en-us/articles/35438085954196-Overview
#
# Done! 15/34 articles successfully extracted
#
# Retry done. Success: 879/932
# Improved by: 15
# Still missing 19 URLs.
